# %% [markdown]
# <a id="the_top"></a>
#
# ### [Journals Home](#the_top) | [About the AI Code](#about_ai_code)
# ---------
# # Crepuscular Rays
#
# ## Attention Shifting Perception edition

# %%
from openai import OpenAI

journals = {
    'vectors': ['84']
}

prompt = ''

client = OpenAI()
github_root = "https://antfriend.github.io/journals/"

print('## Your Table of Contents for this Generated Collection!')
# Iterating through each journal and its pages
for journal, pages in journals.items():
    for page_number in pages:
        journal_image_name = journal + "_" + page_number
        image_url = github_root + journal + "/" + journal_image_name + ".png"

        # Generating the response
        response = client.chat.completions.create(
            model="gpt-4-o",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": prompt},
                        {"type": "image_url", "image_url": {"url": image_url}}
                    ]
                }
            ],
            max_tokens=1000
        )
        print(' ')
        title=''
        message_content = response.choices[0].message.content
        lines = message_content.split('\n')
        if lines:
            title = lines[0]

        title_link_md = '### ' + journal + ' pg.' + page_number + ' [' + title + '](' + journal_image_name + '.html)'
        print(' ')
        print(title_link_md)
        print(' ')
        print(message_content)
        print(' ')
        with open(journal_image_name + '.txt', 'w') as file:
            file.write(message_content)
print(' end ')
# Out:
# ## Your Table of Contents for this Generated Collection!
#
#
# ### vectors pg.38 [As a speechwriter and public speaking coach, helping clients craft TED-style presentations is one of the unique joys of my profession. Based on the image you provided and the text written on it, I will guide you through the steps to create a speech that captures the imagination and inspires transformation. Let's start by crafting an outline for a speech we could title:](vectors_38.html)
#
# As a speechwriter and public speaking coach, helping clients craft TED-style presentations is one of the unique joys of my profession. Based on the image you provided and the text written on it, I will guide you through the steps to create a speech that captures the imagination and inspires transformation. Let's start by crafting an outline for a speech we could title:
#
# **"The Unseen Threads: Uniting Humanity's Tapestry of Perception"**
#
# **Step 1: Key Theme and Idea**
# The key theme of the speech revolves around the diversity of human perception and the unifying undercurrent that connects us all. Our central idea posits that while each person sees the world through a lens colored by their experiences, culture, and beliefs, there remains a shared humanity that binds us. This concept not only resonates across a global audience but also has profound implications for empathy, communication, and collaboration.
#
# **Step 2: Captivating Opening Options**
#
# 1. "Imagine if the colors you saw were experienced differently by the person sitting next to you. What if I told you that this isn't just imagination, but a peek into the reality of human perception?"
# 2. "They say seeing is believing. But what happens when two pairs of eyes see the very same thing, entirely differently? That's the riddle of human perception."
# 3. "Did you know that every person in this room is living in a slightly different version of reality? Let me show you why that is not only fascinating but incredibly important."
# 4. "A philosopher once asked: if a tree falls in a forest and no one is around to hear it, does it make a sound? Now, I ask you, if we all look at a tree, do we really see the same thing?"
# 5. "Close your eyes for a moment and picture a tree. Now open them. I guarantee that no two people here imagined the exact same tree. And there lies the beauty—and complexity—of the human mind."
#
# **Step 3: Structure of the Speech Body**
#
# Opening with our captivating introduction, we will delve into the body of the speech:
#
# - Explore the science of perception and how it differs among individuals, citing studies from psychology and neuroscience.
# - Share compelling stories of people who experience the world uniquely, such as those with synesthesia, to illustrate the diversity of human perception.
# - Contrast these individual experiences with moments of collective emotion, like reactions to art or music, demonstrating our shared human core.
# - Discuss the significance of acknowledging and respecting diverse perspectives for better communication and collaboration in global contexts.
#
# **Step 4: Rhetorical Devices and Storytelling**
#
# To embellish the narrative with rhetorical devices and storytelling:
#
# - Employ metaphors such as "seeing the world through different colored lenses" to help conceptualize individual perception.
# - Use analogies, likening the variety of human experiences to an intricate mosaic where each piece contributes to the overall beauty.
# - Weave in personal anecdotes and vivid imagery such as shared experiences of wonder during momentous events, or the universal language of laughter, to connect emotionally with the audience.
#
# **Step 5: Powerful Ending**
#
# Concluding our speech, we'll leave the audience with something to ponder:
#
# - Emphasize the call to action: Challenge the audience to engage with one another acknowledging their distinct worldviews as opportunities for enrichment rather than division.
# - Pose a thought-provoking question: "How might our world change if we navigated life with the acknowledgment that each person's reality is as unique as their fingerprint, yet as connected as the stars in the sky?"
# - End with a resonant statement: "In the tapestry of human experience, our individual threads may vary in color and texture, yet it's the interweaving of these threads that reveals the true masterpiece—our shared humanity."
#
# This speech structure, punctuated with vivid storytelling, sound science, and emotional resonance, adheres to the spirit of TED Talks, aiming to inform, inspire, and ignite meaningful conversations across the globe.
#
#
#
# ### prints pg.sleestack [Step 1: Key Theme and Idea of the Speech](prints_sleestack.html)
#
# Step 1: Key Theme and Idea of the Speech
#
# Title: “The Unseen Connection: Embracing the Alien Within Us All”
#
# Key Idea: This speech will explore the concept that innovation, creativity, and progress stem from our capacity to embrace the 'alien'—the unfamiliar, the unknown, and the unexplored within us and in the world around us. It argues that by recognizing and nurturing our inner 'alien', we unlock the potential for transformative growth and collective advancement.
#
# Step 2: Captivating Openings
#
# Opening 1: “Did you know that every one of us shares 99% of our DNA with every other person, and yet it is the remaining 1% that makes us uniquely ourselves? Today, I invite you to discover the 'alien' 1% that can reshape the world.”
#
# Opening 2: “Imagine you are an astronaut, setting foot on an uncharted planet, where every rock could hold the key to a new discovery. Now, imagine that this planet is not light-years away—it's within you. It's called your potential.”
#
# Opening 3: “There's an 'alien' artifact sitting in every one of our minds. It's called an idea. An idea so powerful and strange, it can alter the course of history. Are you ready to unearth it?”
#
# Opening 4: “Who here feels like an outsider, a stranger, an 'alien' in their own life or work? What if I told you, that feeling alien is not a deficit, but your greatest asset?”
#
# Opening 5: “When we talk about aliens, we think of extraterrestrial life. But what about the alien concepts, perspectives, and insights that live within each of us, waiting to be released into the world?”
#
# Step 3: Structure of the Speech Body
#
# Point 1: Embrace the unfamiliar within you.
# - Share personal anecdotes and stories of individuals who have tapped into their unique views (without conforming to the norm) to create profound change.
#
# Point 2: Explore the value of diverse perspectives.
# - Discuss research on the benefits of diversity in thought and culture in driving innovation.
#
# Point 3: Overcome the fear of the unknown.
# - Present examples of times when venturing into unexplored territory led to significant breakthroughs in science, technology, and social progress.
#
# Point 4: Collaborate with 'aliens'.
# - Highlight successful interdisciplinary collaborations and how bringing 'aliens' together from different fields has resulted in creative solutions to complex problems.
#
# Step 4: Rhetorical Devices and Storytelling Techniques
#
# - Use metaphors like "The Mind's Uncharted Territories" or "Cultural Cross-Pollination" to capture imagination.
# - Incorporate analogies, comparing the fusion of diverse ideas to the creation of a masterpiece from a palette of distinct colors.
# - Deploy vivid imagery to describe the excitement, mystery, and potential of exploring the 'alien' within us and around us.
#
# Step 5: Concluding with a Powerful Ending
#
# “In the vast cosmos of our collective potential, it's the 'alien' ideas that are the stars waiting to be navigated. As we stand here on this shared platform, I challenge you to be the astronaut of your own life—embrace the 'alien', champion the unfamiliar, and transform the world. Let's not fear the unknown. Let's explore it together and see what extraordinary innovations we can find. Thank you.”
#
# This speech is designed to be adaptable so that the speaker can insert their personal stories or organizational experiences into the framework to personalize the message. The goal is to inspire and provoke the audience to action, emboldening them to embrace and explore the unknown—the 'alien'—for the betterment of all.
#
#  end
